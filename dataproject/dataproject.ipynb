# %% [markdown]
# # Data Project on the Distribution and Specification of Births in Denmark
# ## Group: De Slemme Programmeringsrotter

# %% [markdown]
# We would like to research number of births in Denmark. We would like to find out, where in Denmark most births take place, in terms of municipialities, and we would like to show this visuay through interactive plots. Therefore, we have chosen a dataset from DST and Dataforsyningen, such that we can separate births into municipialities for different years, and display the distribution.

# %%
# uncomment below if you need to install 
# %pip install git+https://github.com/alemartinello/dstapi
# %pip install pandas-datareader

# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

from dstapi import DstApi

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. Read and clean data

# %% [markdown]
# The table in DST for births for each municipiality is called 'FODIE'. Here we load the data and gain an overview. It also contains data for the gender of the new-born baby and national origin and age of the mother. We first load the data.

# %%
# Load data
ind = DstApi('FODIE') 
tabsum = ind.tablesummary(language='en')

# Quick overview of data. 
for variable in tabsum['variable name']:
   print(variable+':')
   display(ind.variable_levels(variable, language='en'))
# Out:
# Table FODIE: Live births by region, mothers ancestry, mothers country of origin, mothers citizenship, age of mother, sex of child and time
# Last update: 2023-02-10T08:00:00
# OMRÅDE:
#       id                text
# 0    000         All Denmark
# 1    084  Region Hovedstaden
# 2    101          Copenhagen
# 3    147       Frederiksberg
# 4    155              Dragør
# ..   ...                 ...
# 100  773               Morsø
# 101  840              Rebild
# 102  787             Thisted
# 103  820     Vesthimmerlands
# 104  851             Aalborg
#
# [105 rows x 2 columns]
# MOHERK:
#   id                      text
# 0  5  Persons of Danish origin
# 1  4                Immigrants
# 2  3                Descendant
# 3  0            Unknown origin
# MOOPRIND:
#        id             text
# 0    5100          Denmark
# 1    5122          Albania
# 2    5124          Andorra
# 3    5706          Belarus
# 4    5126          Belgium
# ..    ...              ...
# 236  5275          Vanuatu
# 237  5532       East Timor
# 238  5599  Pacific Islands
# 239  5103        Stateless
# 240  5999       Not stated
#
# [241 rows x 2 columns]
# MOSTAT:
#        id             text
# 0    5100          Denmark
# 1    5122          Albania
# 2    5124          Andorra
# 3    5706          Belarus
# 4    5126          Belgium
# ..    ...              ...
# 236  5275          Vanuatu
# 237  5532       East Timor
# 238  5599  Pacific Islands
# 239  5103        Stateless
# 240  5999       Not stated
#
# [241 rows x 2 columns]
# MODERSALDER:
#     id      text
# 0   10  10 years
# 1   11  11 years
# 2   12  12 years
# 3   13  13 years
# 4   14  14 years
# 5   15  15 years
# 6   16  16 years
# 7   17  17 years
# 8   18  18 years
# 9   19  19 years
# 10  20  20 years
# 11  21  21 years
# 12  22  22 years
# 13  23  23 years
# 14  24  24 years
# 15  25  25 years
# 16  26  26 years
# 17  27  27 years
# 18  28  28 years
# 19  29  29 years
# 20  30  30 years
# 21  31  31 years
# 22  32  32 years
# 23  33  33 years
# 24  34  34 years
# 25  35  35 years
# 26  36  36 years
# 27  37  37 years
# 28  38  38 years
# 29  39  39 years
# 30  40  40 years
# 31  41  41 years
# 32  42  42 years
# 33  43  43 years
# 34  44  44 years
# 35  45  45 years
# 36  46  46 years
# 37  47  47 years
# 38  48  48 years
# 39  49  49 years
# 40  50  50 years
# 41  51  51 years
# 42  52  52 years
# 43  53  53 years
# 44  54  54 years
# 45  55  55 years
# 46  56  56 years
# 47  57  57 years
# 48  58  58 years
# 49  59  59 years
# 50  60  60 years
# 51  61  61 years
# 52  62  62 years
# 53  63  63 years
# 54  64  64 years
# BARNKON:
#   id   text
# 0  D   Boys
# 1  P  Girls
# Tid:
#       id  text
# 0   2007  2007
# 1   2008  2008
# 2   2009  2009
# 3   2010  2010
# 4   2011  2011
# 5   2012  2012
# 6   2013  2013
# 7   2014  2014
# 8   2015  2015
# 9   2016  2016
# 10  2017  2017
# 11  2018  2018
# 12  2019  2019
# 13  2020  2020
# 14  2021  2021
# 15  2022  2022

# %% [markdown]
# We notice that 'OMRÅDE' can take the value 'All Denmark', the regions as well as the individual municipialities. We keep this in mind when further investigating, so we don't get duplicates across the categories (as a birth will be registered in both a municipiality, a region and all of Denmark).

# %%
# The _define_base_params -method gives us a nice template (selects all available data)
params = ind._define_base_params(language='en')
params
# Out:
# {'table': 'fodie',
#  'format': 'BULK',
#  'lang': 'en',
#  'variables': [{'code': 'OMRÅDE', 'values': ['*']},
#   {'code': 'MOHERK', 'values': ['*']},
#   {'code': 'MOOPRIND', 'values': ['*']},
#   {'code': 'MOSTAT', 'values': ['*']},
#   {'code': 'MODERSALDER', 'values': ['*']},
#   {'code': 'BARNKON', 'values': ['*']},
#   {'code': 'Tid', 'values': ['*']}]}

# %% [markdown]
# For practical reasons and to gain further insight we sort the datasat, in an order we find suitable. We start by years, then miúnicipiality, than the age of the mother etc.

# %%
inc_api =pd.DataFrame(ind.get_data(params=params))
inc_api.sort_values(by=['TID', 'OMRÅDE', 'MODERSALDER', 'MOOPRIND', 'BARNKON'], inplace=True)

# %% [markdown]
# ## 2. Explore each data set

# %% [markdown]
# First we examine how large the dataframe is:

# %%
print(inc_api.shape)
# Out:
# (412674, 8)

# %% [markdown]
# There seems to be 412674 rows (observations) and 8 columns (variables). The 7 rows are of course the groups as seen in section 'Read and clean data'. But what is the 8th- we take a look?
#
# First we would simply like to see a the data as a dataframe and what a row could look like:

# %%
inc_api.head(5)
# Out:
#           OMRÅDE                    MOHERK MOOPRIND   MOSTAT MODERSALDER  \
# 329917  Aabenraa                Descendant  Germany  Denmark    17 years
# 305207  Aabenraa                Immigrants  Armenia  Armenia    18 years
# 301436  Aabenraa  Persons of Danish origin  Denmark  Denmark    18 years
# 324174  Aabenraa  Persons of Danish origin  Denmark  Denmark    18 years
# 329923  Aabenraa                Immigrants     Iraq     Iraq    18 years
#
#        BARNKON   TID  INDHOLD
# 329917    Boys  2007        1
# 305207   Girls  2007        1
# 301436    Boys  2007        2
# 324174   Girls  2007        2
# 329923    Boys  2007        1

# %%
inc_api.tail(5)
# Out:
#        OMRÅDE                    MOHERK MOOPRIND   MOSTAT MODERSALDER BARNKON  \
# 389354    Ærø                Immigrants  Germany  Germany    36 years   Girls
# 389369    Ærø  Persons of Danish origin  Denmark  Denmark    38 years   Girls
# 389370    Ærø  Persons of Danish origin  Denmark  Denmark    41 years   Girls
# 389371    Ærø  Persons of Danish origin  Denmark  Denmark    42 years    Boys
# 389372    Ærø  Persons of Danish origin  Denmark  Denmark    44 years   Girls
#
#          TID  INDHOLD
# 389354  2022        1
# 389369  2022        1
# 389370  2022        2
# 389371  2022        1
# 389372  2022        1

# %% [markdown]
# It appears that the 8th the column (variable) is 'INDHOLD'. 'INDHOLD' seems to show the amount of births in the specific category of the other 7 variables.
#
# If we try to sort by 'INDHOLD' to examine the rows where 'INDHOLD' is large, we would expect to see the categories of 'Persons of Danish origin' and a age of the mother of roughly late twenties. We examine this:

# %%
inc_api.sort_values(by=['INDHOLD'], inplace=True)
inc_api.tail(5)
# Out:
#              OMRÅDE                    MOHERK MOOPRIND   MOSTAT MODERSALDER  \
# 360699  All Denmark  Persons of Danish origin  Denmark  Denmark    29 years
# 351557  All Denmark  Persons of Danish origin  Denmark  Denmark    31 years
# 227982  All Denmark  Persons of Danish origin  Denmark  Denmark    29 years
# 333961  All Denmark  Persons of Danish origin  Denmark  Denmark    31 years
# 333962  All Denmark  Persons of Danish origin  Denmark  Denmark    30 years
#
#        BARNKON   TID  INDHOLD
# 360699    Boys  2007     2359
# 351557   Girls  2007     2361
# 227982    Boys  2021     2371
# 333961    Boys  2007     2400
# 333962    Boys  2007     2410

# %% [markdown]
# The table above shows us, as expected, that 'INDHOLD' is the birth count for the category. E.g. there have been 2410 boys born by women of Danish origin aged 30 years in 2007 in all of Denmark.
#
# We now have a dataset we can analyze.

# %% [markdown]
# # 3 Analysis

# %% [markdown]
# ## 3.1 Analysis of number of children born by mother origin and gender

# %% [markdown]
# Now we would like to analyze the data. First let us investigate the amount of children born in a specific year, the gender of them and the origin of the mother. We choose to use 2019 as an example. See code below:

# %%
# Select only the category 'All Denmark' from the area in which the child was born.
# One should either choose 'All Denmark' or all of the individual municipialities when analyzing the data to get the levels correct, as a child is registered in both categories.
all_denmark_data = inc_api[inc_api['OMRÅDE'] == 'All Denmark']

# Select the data for the year 2019
all_denmark_data2 = all_denmark_data.set_index('TID')
year_data = all_denmark_data2.loc[all_denmark_data2.index.get_level_values('TID') == 2019]

# Group data by gender of child and origin of mother. 
grouped_data = year_data.groupby(['BARNKON', 'MOHERK'])['INDHOLD'].sum()

# check data out
print(grouped_data)
# Out:
# BARNKON  MOHERK
# Boys     Descendant                   1156
#          Immigrants                   5781
#          Persons of Danish origin    24582
# Girls    Descendant                   1037
#          Immigrants                   5430
#          Persons of Danish origin    23181
# Name: INDHOLD, dtype: int64

# %% [markdown]
# Let's check if this is realistic. We aggregate the number of births, then have total amount of live births in Denmark in 2019:

# %%
sum = grouped_data.sum()
print("The total amount of live births in Denmark in 2019 was: " + str(sum))
# Out:
# The total amount of live births in Denmark in 2019 was: 61167

# %% [markdown]
#  A quick check on the [DST website](https://www.dst.dk/en/Statistik/emner/borgere/befolkning/foedsler) shows that the amount of live births in Denmark in 2019 was 61167. It uses the same table as us, and this shows us that we have aggregated the categories correctly. Thus, we conclude we have no bug in our code or method.
#
#  We can therefore kick-off the first analysis. *Figure 1* shows the number of children born in Denmark, where the colors represent if the mother is of foreign or Danish origin, if this is known. The two columns represent boys and girls respectively. To address different years, we coded a yearslider in the end of the code, which can be moved to change the plot for a specific year.

# %%
import ipywidgets as widgets

# Define a function to update the plot based on the selected year
def update_plot(year):

    # Select the data for the selected year
    year_data = all_denmark_data.loc[all_denmark_data['TID'] == year]

    # Group data by gender of child and origin of mother.
    grouped_data = year_data.groupby(['MOHERK', 'BARNKON'])['INDHOLD'].sum()

    # Transform the data into a format suitable for a stacked bar chart
    stacked_data = grouped_data.unstack(level=0)

    # Create the stacked bar chart
    ax = stacked_data.plot(kind='bar', stacked=True)

    # Move the legend to the right of the plot
    ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

    # Add chart labels and title
    plt.title(f'Figure 1: Number of Children Born in Denmark in {year} by Mother Origin and Gender')
    plt.xlabel('Childs gender')
    plt.ylabel('Number of Children Born')

    # Add labels to the stacked bars
    for container in ax.containers:
        for i, bar in enumerate(container):
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, height / 2, int(height), ha='center', va='center', color='black', fontsize=12)

widgets.interact(update_plot,
                 year=widgets.IntSlider(value=2019, min=2007, max=2021, step=1, description='Year', continuous_update=False),
)
# Out:
# interactive(children=(IntSlider(value=2019, continuous_update=False, description='Year', max=2021, min=2007), …
# <function __main__.update_plot(year)>

# %% [markdown]
# From the interactive plot above we can easily see that in general, more boys are born than girls. Furthermore, by far the largest part of births are by mothers of danish origin. Then by immigrants and then by descendants.

# %% [markdown]
# ## 3.2 Merge data sets and analysis of birth in each municipality in Denmark (including heat map)

# %% [markdown]
# We would now like to create a interactive map of Denmark where the total number of births in each municipiality is shown as a heatmap.
#
# To achieve this first find and load geodata of Denmark and municipalities. To do this use the package 'GeoPandas' and load a gml-dataset from Dataforsyningen - "ADMINISTRATIVE ENHEDER' from link: https://dataforsyningen.dk/data/992.
#
# To install geopandas use code 'conda install geopandas' in anaconda terminal prompt.

# %%
import geopandas as gpd

# Load the data into a GeoDataFrame
gdf = gpd.read_file("DK_AdministrativeUnit.gml")

# Visualize the data and set the title
ax = gdf.plot()
ax.set_title("Figure 2: Map of Denmark")

# Display the plot
plt.show()

# %% [markdown]
# It looks like we have correctly gotten data for denmark. Lets see what the other data looks like:

# %%
gdf.head(1)
# Out:
#          gml_id    identifier  nationalCode  localId  \
# 0  dk.au.389120  dk.au.389120           187   389120
#
#                                            namespace            versionId  \
# 0  https://geo.data.gov.dk/dataset/50f84f74-a55a-...  2018-01-22T09:00:00
#
#   LocalisedCharacterString language sourceOfName pronunciation        text  \
# 0                  Kommune      dan         None          None  Vallensbæk
#
#   script residenceOfAuthority beginLifespanVersion boundary upperLevelUnit  \
# 0   Latn                 None  2018-01-22T09:00:00     None           None
#
#                                             geometry
# 0  MULTIPOLYGON (((710270.910 6171295.650, 710273...

# %%
gdf.tail(1)
# Out:
#            gml_id    identifier  nationalCode  localId  \
# 103  dk.au.389204  dk.au.389204           840   389204
#
#                                              namespace            versionId  \
# 103  https://geo.data.gov.dk/dataset/50f84f74-a55a-...  2018-01-22T09:00:00
#
#     LocalisedCharacterString language sourceOfName pronunciation    text  \
# 103                  Kommune      dan         None          None  Rebild
#
#     script residenceOfAuthority beginLifespanVersion boundary upperLevelUnit  \
# 103   Latn                 None  2018-01-22T09:00:00     None           None
#
#                                               geometry
# 103  MULTIPOLYGON (((538851.620 6300672.150, 538851...

# %% [markdown]
# It seems that 'nationalCode' is the municipality-ID to match the 'text' column that shows the municipality name. The geodata-polygon seems to be located in the 'geometry' column.
#
# We clean up the dataset by only keeping those variables:

# %%
gdf = gdf.loc[:, ['nationalCode', 'text', 'geometry']]
gdf
# Out:
#      nationalCode                text  \
# 0             187          Vallensbæk
# 1             147       Frederiksberg
# 2             175             Rødovre
# 3             161            Glostrup
# 4             153             Brøndby
# ..            ...                 ...
# 99           1082  Region Midtjylland
# 100          1081  Region Nordjylland
# 101          1085     Region Sjælland
# 102          1083   Region Syddanmark
# 103           840              Rebild
#
#                                               geometry
# 0    MULTIPOLYGON (((710270.910 6171295.650, 710273...
# 1    MULTIPOLYGON (((721665.510 6177836.640, 721620...
# 2    MULTIPOLYGON (((716883.100 6174216.660, 716885...
# 3    MULTIPOLYGON (((715545.380 6175968.680, 715547...
# 4    MULTIPOLYGON (((716885.550 6174191.990, 716883...
# ..                                                 ...
# 99   MULTIPOLYGON (((548297.190 6268767.710, 548292...
# 100  MULTIPOLYGON (((476091.820 6285490.440, 476088...
# 101  MULTIPOLYGON (((670291.600 6178301.520, 670291...
# 102  MULTIPOLYGON (((548131.600 6089172.750, 548130...
# 103  MULTIPOLYGON (((538851.620 6300672.150, 538851...
#
# [104 rows x 3 columns]

# %% [markdown]
# From the above we can see that there also exists data for the different Regions. We are not interested in this data as for now and will therefore remove them such that rows are only for munipalities. To remove them start by investigating how many values from 'text' start with 'Region':

# %%
def unique(list):
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list:
        # check if the element starts with "Region" and if it exists in unique_list or not
        if x.startswith("Region") and x not in unique_list:
            unique_list.append(x)
    
    # print list
    for x in unique_list:
        print(x)


    return unique_list
        

list1 = gdf['text']
uniq = unique(list1)
print(uniq)
# Out:
# Region Hovedstaden
# Region Midtjylland
# Region Nordjylland
# Region Sjælland
# Region Syddanmark
# ['Region Hovedstaden', 'Region Midtjylland', 'Region Nordjylland', 'Region Sjælland', 'Region Syddanmark']

# %% [markdown]
# This is as expected. We know that Denmark has 5 regions. Now remove these regions from the dataset:

# %%
# remove rows where text is in the remove_list using boolean indexing with ~ operator
gdf = gdf[~gdf['text'].isin(uniq)]
gdf
# Out:
#      nationalCode           text  \
# 0             187     Vallensbæk
# 1             147  Frederiksberg
# 2             175        Rødovre
# 3             161       Glostrup
# 4             153        Brøndby
# ..            ...            ...
# 94            851        Aalborg
# 95            376   Guldborgsund
# 96            390    Vordingborg
# 97            400       Bornholm
# 103           840         Rebild
#
#                                               geometry
# 0    MULTIPOLYGON (((710270.910 6171295.650, 710273...
# 1    MULTIPOLYGON (((721665.510 6177836.640, 721620...
# 2    MULTIPOLYGON (((716883.100 6174216.660, 716885...
# 3    MULTIPOLYGON (((715545.380 6175968.680, 715547...
# 4    MULTIPOLYGON (((716885.550 6174191.990, 716883...
# ..                                                 ...
# 94   MULTIPOLYGON (((563346.420 6325579.150, 563336...
# 95   MULTIPOLYGON (((688764.820 6051969.090, 688758...
# 96   MULTIPOLYGON (((710006.200 6101733.040, 710010...
# 97   MULTIPOLYGON (((891862.380 6126874.580, 891863...
# 103  MULTIPOLYGON (((538851.620 6300672.150, 538851...
#
# [99 rows x 3 columns]

# %% [markdown]
# Thus we now have 99 rows equivalent to the municipalities in copenhagen (98 real ones 'Christiansø' as special administrative region).
#
# We now wish to *join* the births data onto this geodata. First prepare the births data:

# %%
# Select OMRÅDE column from the births data
list2 = inc_api['OMRÅDE']

# Find unique values in the births data that start with 'Region'
uniq2 = unique(list2)

# Append the category 'All Denmark' to the list.
uniq2.append('All Denmark')
print(uniq2)
# Out:
# Region Hovedstaden
# Region Sjælland
# Region Syddanmark
# Region Nordjylland
# Region Midtjylland
# ['Region Hovedstaden', 'Region Sjælland', 'Region Syddanmark', 'Region Nordjylland', 'Region Midtjylland', 'All Denmark']

# %% [markdown]
# As seen above the list 'uniq2' now contains all the valeus that are not municipalities from the births data dataset. Thus, we expect that there should now be 99 unique values for 'OMRÅDE' in the births dataset when removing the values from 'uniq2':

# %%
inc_api2 = inc_api[~inc_api['OMRÅDE'].isin(uniq2)]
unique_områder = inc_api['OMRÅDE'].nunique()
unique_områder2 = inc_api2['OMRÅDE'].nunique()
print("Amount of unique values when not removing 'Regions%' and 'All Denmark':  " + str(unique_områder))
print("Amount of unique values when removing 'Regions%' and 'All Denmark':      " + str(unique_områder2))
print("Where '%' indicates an arbitrary string following 'Region'.")
# Out:
# Amount of unique values when not removing 'Regions%' and 'All Denmark':  105
# Amount of unique values when removing 'Regions%' and 'All Denmark':      99
# Where '%' indicates an arbitrary string following 'Region'.

# %% [markdown]
# As expected. Now we aggregate the births data into categories; Births, Municipality, Year so that we can properly merge it with the map data.

# %%
# Group data by gender of child and origin of mother. 
births = inc_api2.groupby(['OMRÅDE','TID'])['INDHOLD'].sum()
births_df = births.reset_index()

# A quick check tells us that aggregating for 2019 like earlier gives us the same amount of births
year_data = births.loc[births.index.get_level_values('TID') == 2019]

sum_births = grouped_data.sum()
print("The total amount of live births in Denmark in 2019 was: " + str(sum_births))
# Out:
# The total amount of live births in Denmark in 2019 was: 61167

# %% [markdown]
# Now we merge the births data onto the geodata. First we are interested in seeing if any values do not have a match between 'text' and 'OMRÅDE'. As the string is not given as e.g. a code we expect there might be differences.

# %%
merged_data = pd.merge(gdf, births_df[['OMRÅDE', 'TID', 'INDHOLD']], left_on='text', right_on='OMRÅDE', how='outer', indicator=True)

# Select the rows where _merge is equal to 'right_only'
unmatched_values = merged_data.loc[merged_data['_merge'] == 'right_only', 'OMRÅDE']

# Select only the unique non-matching values
unique_unmatched_values = unmatched_values.unique()

print(unique_unmatched_values)
# Out:
# ['Copenhagen']

# %% [markdown]
# Thus it seems that for some reason the municipality for Copenhagen in the births data is written in english and not danish like the rest of the municipalities. This is fixed in the before the merge below:

# %%
births_df['OMRÅDE'] = births_df['OMRÅDE'].replace('Copenhagen', 'København')
merged_data = pd.merge(gdf, births_df[['OMRÅDE', 'TID', 'INDHOLD']], left_on='text', right_on='OMRÅDE', how='outer', indicator=True)

# Select the rows where _merge is equal to 'right_only'
unmatched_values = merged_data.loc[merged_data['_merge'] == 'right_only', 'OMRÅDE']

# Select only the unique non-matching values
unique_unmatched_values = unmatched_values.unique()

print(unique_unmatched_values)
# Out:
# []

# %% [markdown]
# As seen above now we do not have any non-matched values.

# %% [markdown]
# Now before making a map select investigate the size of the data for different years:

# %%
years = [2005, 2008, 2010, 2015, 2019, 2022]

merged_data2 = merged_data.set_index(['TID', 'OMRÅDE'])

for year in years:
    subset = merged_data2[merged_data2.index.get_level_values('TID') == year]
    print("Number of rows and columns for year {}: {}".format(year, subset.shape))
# Out:
# Number of rows and columns for year 2005: (0, 5)
# Number of rows and columns for year 2008: (99, 5)
# Number of rows and columns for year 2010: (99, 5)
# Number of rows and columns for year 2015: (98, 5)
# Number of rows and columns for year 2019: (98, 5)
# Number of rows and columns for year 2022: (99, 5)

# %% [markdown]
# Notice only 98 rows. This is likely as Christiansø has very few births (1 birth in 2022 and 0 in 2019). We see the difference beetween the values:

# %%
subset_2019 = merged_data2[merged_data2.index.get_level_values('TID') == 2019]
subset_2022 = merged_data2[merged_data2.index.get_level_values('TID') == 2022]

unique_2019 = set(subset_2019['text'].unique())
unique_2022 = set(subset_2022['text'].unique())

difference = unique_2022 - unique_2019

print("Unique values in 2022 but not 2019:", difference)
# Out:
# Unique values in 2022 but not 2019: {'Christiansø'}

# %% [markdown]
# Thus we have found the *anomaly* - and that it is nothing to worry about. Now we are going to make the map with geopandas and make it interactable such that one can choose year. For easier plotting we will add the rows where Christiansø has zero births - instead of it being missing:

# %% [markdown]
# Before mapping we are going to create intervals for number of births for better display in a choropleth plot:

# %%
# Define the intervals and labels
bins = [0, 100, 500, 1000, 5000, 1000000]
labels = ['0-100', '100-500', '500-1000', '1000-5000', '5000+']

# %%
import ipywidgets as widgets

# Define a function to update the plot based on the selected year
def update_cholo(year):

    # Use cut() to assign labels to intervals
    subset_year =  merged_data2[merged_data2.index.get_level_values('TID') == year]

    subset = subset_year.copy()
    subset.loc[:, 'intervals'] = pd.cut(subset['INDHOLD'], bins=bins, labels=labels)

    # Calculate summary statistics
    max_val = subset['INDHOLD'].max()
    mean_val = subset['INDHOLD'].mean()

    # Create plot title without summary statistics
    title = f'Figure 3: Amount of live born children in {year}'

    # Create text string with summary statistics
    stats_text = f'Maximum: {max_val}, Mean: {mean_val:.2f}'

    ax = subset.plot("intervals",cmap='OrRd', legend = True, figsize=(14, 8), edgecolor='black')
    ax.axis('off')
    ax.set_title(title)

    # Add summary statistics as a text box on the plot
    ax.text(0.5, 0.9, stats_text, transform=ax.transAxes, fontsize=14, bbox=dict(facecolor='white', edgecolor='black', alpha=0.8))

    # Adjust the legend size and position
    legend = ax.get_legend()
    legend.set_bbox_to_anchor((0.85, 0.8))
    legend.prop.set_size(30)

    # Increase marker size in legend and add black border
    for line in legend.get_lines():
        line.set_markersize(15)
        line.set_markeredgewidth(1.5)
        line.set_markeredgecolor('black')

    # Set font size for all legend labels
    for label in legend.get_texts():
        label.set_fontsize(16)


widgets.interact(update_cholo,
                 year=widgets.IntSlider(value=2019, min=2008, max=2021, step=1, description='Year', continuous_update=False, layout=widgets.Layout(width='30%')),
)
# Out:
# interactive(children=(IntSlider(value=2019, continuous_update=False, description='Year', layout=Layout(width='…
# <function __main__.update_cholo(year)>

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# We have now established a data project, including different interactive visualisations to display the findings. Our main contribution is that we have specified the amount of mothers giving birth being of danish origin vs. others, while also displaying the geographic distribution of births in Denmark. The conclusion is that the greatest cities has the greatest amount of births. Further, the early findings suggest that most births are given while mother's in late 20's/early 30's.
#
# A potential further investigation would be to account for different levels of populations across the cities, to enable a more sophisticated analysis of potential behavioural differences across cities, which leads to different patterns of birth-giving.
